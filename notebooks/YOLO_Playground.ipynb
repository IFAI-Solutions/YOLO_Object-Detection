# %% [markdown]
# # Object Detection Model - Playground
#
# Playground to test and validate the Object Detection Model with the webcam

# %% [markdown]
# ---

# %% [markdown]
# ## Inizialitation 📚

# %%
# Libraries
from ultralytics import YOLO
import cv2
import os

# Dynamic path set up
current_dir = os.getcwd()
if os.path.basename(current_dir) == 'notebooks':
    os.chdir('..')

print(f"Working Directory: {os.getcwd()}")

# %% [markdown]
# ## Loading the model ℹ️

# %%
# Select the model to use
model = YOLO('runs/detect/CocaCola_Model/weights/best.pt')

# Select the external webcam
cap = cv2.VideoCapture(0)

while cap.isOpened():

    # Read the frame
    ret, frame = cap.read()
    if not ret: # condition to break the loop
        break
    
    # Run the model over the frame
    results = model(frame)
    
    # Show the result s
    annotated_frame = results[0].plot()
    
    # Visualize results
    cv2.imshow('YOLO Inference', annotated_frame)
    
    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Release the webcam and close the window
cap.release()
cv2.destroyAllWindows()
